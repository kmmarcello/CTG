# %% [markdown]
# ## Importing Python Modules

# %%
from Bio import SeqIO
import os
from Bio.SeqUtils.ProtParam import ProteinAnalysis
from Bio.Seq import Seq
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Defining Paths and Variables

# %%
km_path = "/Users/kaylahmarcello/Desktop/projects/amino_acids/data/" 
aliphatic_index = ["A", "V", "I", "L"]
acidic = ["D", "E"]

# %% [markdown]
# ## Calculations

# %%
import csv

with open(os.path.join(km_path,"PsbA.fa")) as handle: 
        f = open('PsbA.csv', 'w')
        writer = csv.writer(f)
        header = ['name', 'proline count', 'arginine count', 'lysine count', 'r/k ratio', 'aliphatic percent sum', 'aromaticity', 'flexibility sum', 'flexibility_avg', 'gravy']
        writer.writerow(header)
        for record in SeqIO.parse(handle, "fasta"):
            print(record.id)                       # printing the gene id
            #print(vars(record))
            #print(record._seq)
            x = ProteinAnalysis(str(record._seq))  # storing the sequence in a variable
            g_count = x.count_amino_acids()["G"]   # calculating number of G residues
            print("proline count", g_count)
            r_count = x.count_amino_acids()["R"]   # calculating the number of R AA residues
            print("arginine count", r_count)   
            k_count = x.count_amino_acids()["K"]   # calculating the number of K AA residues 
            print("lysine count", k_count)
            if k_count >0:
                r_k_ratio = r_count / k_count      # ratio of R to K, avoiding zero divider 
                print("r/k ratio", r_k_ratio)
            else:
                r_k_ratio = "NA"
            aliphatic_percent_sum = 0              # calculating the percentage of total protein that are aliphatic residues
            for aa in aliphatic_index: 
                    aliphatic_count = x.get_amino_acids_percent()[aa]
                    aliphatic_percent_sum = aliphatic_percent_sum + aliphatic_count
                    #print("aliphatic count", aliphatic_count)
                    #print("aliphatic percent sum", aliphatic_percent_sum)
            print("final aliphatic percent sum", aliphatic_percent_sum)
            acidic_percentage_sum = 0             # calculating percentage of toal protein that are acidic residues
            for aa in acidic: 
                    acidic_percentage = x.get_amino_acids_percent()[aa]
                    acidic_percentage_sum = acidic_percentage_sum + acidic_percentage
                    #print("acidic percentage", acidic_percentage)
                    #print("acidic percentage sum", acidic_percentage_sum)
            print("final acidic percentage sum", acidic_percentage_sum)
            aromaticity = x.aromaticity()         # calculating aromaticity
            print("aromaticity", aromaticity)
            
            flexibility = x.flexibility()         # calculating flexibility 
            #print("flexibility", flexibility)
            flexibility_sum = sum(flexibility)
            print("flexibility sum", flexibility_sum)
            flexibility_avg = (sum(flexibility)/len(flexibility))
            print("flexibility avg", flexibility_avg)
            gravy = x.gravy()                     # calculating gravy
            print("gravy", gravy)
            data = [record.id, g_count, r_count, k_count, r_k_ratio, aliphatic_percent_sum, aromaticity, flexibility_sum, flexibility_avg, gravy]
            writer.writerow(data)
        f.close()
# Out:
# PsbA-Acaryochloris_marina_MBIC11017.fa_2Z87P.faa.final_tree.fa___photo_hmms___fce1b145354508c00ca66b5413cbb64f6017ab19d1701ae6813f341c
# proline count 31
# arginine count 12
# lysine count 3
# r/k ratio 4.0
# final aliphatic percent sum 0.3415977961432507
# final acidic percentage sum 0.05234159779614325
# aromaticity 0.11570247933884298
# flexibility sum 348.63602380952386
# flexibility avg 0.9848475248856606
# gravy 0.4418732782369151
# PsbA-Acaryochloris_marina_MBIC11017.fa_2Z87P.faa.final_tree.fa___photo_hmms___b006de2b636427f602bf6764c7fc74d6d31856eccace1f9c61ad1545
# proline count 34
# arginine count 15
# lysine count 3
# r/k ratio 5.0
# final aliphatic percent sum 0.3190883190883191
# final acidic percentage sum 0.07692307692307693
# aromaticity 0.16524216524216523
# flexibility sum 336.5166428571431
# flexibility avg 0.9839667919799506
# gravy 0.3584045584045584
# PsbA-Acaryochloris_marina_MBIC11017.fa_2Z87P.faa.final_tree.fa___photo_hmms___c106e9b54c199e75274ba5126eb62ce00f3a04d1db2674417fd570de
# proline count 35
# arginine count 13
# lysine count 1
# r/k ratio 13.0
# final aliphatic percent sum 0.3222222222222222
# final acidic percentage sum 0.06388888888888888
# aromaticity 0.14444444444444443
# flexibility sum 345.555797619048
# flexibility avg 0.9844894519061197
# gravy 0.34944444444444406
# PsbA-Acaryochloris_marina_MBIC11017.fa_2Z87P.faa.final_tree.fa___photo_hmms___1d32166138c9cfca954893d74cbb67f18c899d89a4221f4af071f1f2
# proline count 35
# arginine count 13
# lysine count 1
# r/k ratio 13.0
# final aliphatic percent sum 0.3222222222222222
# final acidic percentage sum 0.06388888888888888
# aromaticity 0.14444444444444443
# flexibility sum 345.555797619048
# flexibility avg 0.9844894519061197
# gravy 0.34944444444444406
# PsbA-Acaryochloris_marina_MBIC11017.fa_2Z87P.faa.final_tree.fa___photo_hmms___f1b8b0472e3f8ac6afe4fb22111d82ee7d01d0821c7ef31e69461bc7
# proline count 34
# arginine count 15
# lysine count 3
# r/k ratio 5.0
# final aliphatic percent sum 0.3190883190883191
# final acidic percentage sum 0.07692307692307693
# aromaticity 0.16524216524216523
# flexibility sum 336.5166428571431
# flexibility avg 0.9839667919799506
# gravy 0.3584045584045584
# PsbA-Acaryochloris_marina_MBIC11017.fa_2Z87P.faa.final_tree.fa___photo_hmms___345b74f92efbafe3930bbaa642316be6e6d5d0348a471ea2bdc43377
# proline count 33
# arginine count 16
# lysine count 4
# r/k ratio 4.0
# final aliphatic percent sum 0.3076923076923077
# final acidic percentage sum 0.07692307692307693
# aromaticity 0.16524216524216523
# flexibility sum 336.63578571428576
# flexibility avg 0.9843151629072683
# gravy 0.3424501424501425
# PsbA-Acaryochloris_marina_S15.fa_2Z87P.faa.final_tree.fa___photo_hmms___af14905f5fe512e3c262b688f00c88107175deca9028d097b8b6235a
# proline count 34
# arginine count 15
# lysine count 3
# r/k ratio 5.0
# final aliphatic percent sum 0.3190883190883191
# final acidic percentage sum 0.07692307692307693
# aromaticity 0.16524216524216523
# flexibility sum 336.5556428571431
# flexibility avg 0.9840808270676699
# gravy 0.3689458689458693
# PsbA-Acaryochloris_marina_S15.fa_2Z87P.faa.final_tree.fa___photo_hmms___b68981eec4ece5330e3d6b7fcfba4fb55ff2071e08643bb794376891
# proline count 34
# arginine count 15
# lysine count 3
# r/k ratio 5.0
# final aliphatic percent sum 0.3190883190883191
# final acidic percentage sum 0.07692307692307693
# aromaticity 0.16524216524216523
# flexibility sum 336.5556428571431
# flexibility avg 0.9840808270676699
# gravy 0.3689458689458693
# PsbA-Acaryochloris_marina_S15.fa_2Z87P.faa.final_tree.fa___photo_hmms___f370bf7e054c0a5de1c1652c367d5ec112e1e241ec5f09ede76cc833
# proline count 35
# arginine count 13
# lysine count 1
# r/k ratio 13.0
# final aliphatic percent sum 0.3222222222222222
# final acidic percentage sum 0.06388888888888888
# aromaticity 0.14444444444444443
# flexibility sum 345.555797619048
# flexibility avg 0.9844894519061197
# gravy 0.34944444444444406
# PsbA-Acaryochloris_marina_S15.fa_2Z87P.faa.final_tree.fa___photo_hmms___2a81312202cb8707a2180d4b55db854781fa79adeb35361f1961ec41
# proline count 35
# arginine count 13
# lysine count 1
# r/k ratio 13.0
# final aliphatic percent sum 0.3222222222222222
# final acidic percentage sum 0.06388888888888888
# aromaticity 0.14444444444444443
# flexibility sum 345.555797619048
# flexibility avg 0.9844894519061197
# gravy 0.34944444444444406
# PsbA-Acaryochloris_marina_S15.fa_2Z87P.faa.final_tree.fa___photo_hmms___7026466802d47be44a09d50aaac1e187aa21820e31ce3567e1f581b5
# proline count 35
# arginine count 13
# lysine count 1
# r/k ratio 13.0
# final aliphatic percent sum 0.3222222222222222
# final acidic percentage sum 0.06388888888888888
# aromaticity 0.14444444444444443
# flexibility sum 345.555797619048
# flexibility avg 0.9844894519061197
# gravy 0.34944444444444406
# PsbA-Allocoleopsis_franciscana_PCC_7113.fa_2Z87P.faa.final_tree.fa___photo_hmms___e194641e3ff5d1125e0100f610866d6d640086a35ad41f8f692a3026
# proline count 34
# arginine count 14
# lysine count 1
# r/k ratio 14.0
# final aliphatic percent sum 0.3277777777777778
# final acidic percentage sum 0.06944444444444445
# aromaticity 0.1472222222222222
# flexibility sum 345.90051190476186
# flexibility avg 0.9854715438882105
# gravy 0.32805555555555505
# PsbA-Allocoleopsis_franciscana_PCC_7113.fa_2Z87P.faa.final_tree.fa___photo_hmms___a8cd43cc47ccae3110ac15f64f12647c16b41233d71eb322d7b6d707
# proline count 34
# arginine count 14
# lysine count 1
# r/k ratio 14.0
# final aliphatic percent sum 0.3277777777777778
# final acidic percentage sum 0.06944444444444445
# aromaticity 0.1472222222222222
# flexibility sum 345.90051190476186
# flexibility avg 0.9854715438882105
# gravy 0.32805555555555505
# PsbA-Allocoleopsis_franciscana_PCC_7113.fa_2Z87P.faa.final_tree.fa___photo_hmms___9488a142fc95abe44cb53f302d39663aaf4eb90f13fc79bc06cf333c
# proline count 32
# arginine count 11
# lysine count 1
# r/k ratio 11.0
# final aliphatic percent sum 0.35833333333333334
# final acidic percentage sum 0.06944444444444445
# aromaticity 0.14166666666666666
# flexibility sum 345.6247976190476
# flexibility avg 0.9846860331026998
# gravy 0.3991666666666671
# PsbA-Allocoleopsis_franciscana_PCC_7113.fa_2Z87P.faa.final_tree.fa___photo_hmms___af2cee029d39146be6158e182fa66ce4c74e29eb9ea966aa020d5df1
# proline count 35
# arginine count 14
# lysine count 1
# r/k ratio 14.0
# final aliphatic percent sum 0.3111111111111111
# final acidic percentage sum 0.06666666666666667
# aromaticity 0.14722222222222223
# flexibility sum 345.870273809524
# flexibility avg 0.9853853954687294
# gravy 0.27722222222222176
# PsbA-Allocoleopsis_franciscana_PCC_7113.fa_2Z87P.faa.final_tree.fa___photo_hmms___1624cbdefb734563964d02c0faf3fdea257738836f278d409461e7e1
# proline count 34
# arginine count 16
# lysine count 4
# r/k ratio 4.0
# final aliphatic percent sum 0.3210227272727273
# final acidic percentage sum 0.07386363636363637
# aromaticity 0.1647727272727273
# flexibility sum 337.458642857143
# flexibility avg 0.9838444398167434
# gravy 0.37244318181818303
# PsbA-Allocoleopsis_franciscana_PCC_7113.fa_2Z87P.faa.final_tree.fa___photo_hmms___b68d7bd9b36446c8104b2c25c69af9fa4d2caaa42d0415c47d738432
# proline count 34
# arginine count 16
# lysine count 4
# r/k ratio 4.0
# final aliphatic percent sum 0.3210227272727273
# final acidic percentage sum 0.07386363636363637
# aromaticity 0.1647727272727273
# flexibility sum 337.458642857143
# flexibility avg 0.9838444398167434
# gravy 0.37244318181818303
# PsbA-Allocoleopsis_franciscana_PCC_7113.fa_2Z87P.faa.final_tree.fa___photo_hmms___7069814d4153585bf06efc51da8c1f0a42f5446ada395d23753ae694
# proline count 34
# arginine count 14
# lysine count 1
# r/k ratio 14.0
# final aliphatic percent sum 0.3277777777777778
# final acidic percentage sum 0.06944444444444445
# aromaticity 0.1472222222222222
# flexibility sum 345.89441666666664
# flexibility avg 0.9854541785375118
# gravy 0.335555555555555
# PsbA-Allocoleopsis_franciscana_PCC_7113.fa_2Z87P.faa.final_tree.fa___photo_hmms___4ec25398ba300def56c0ed569499ae06d001902ed89ea15ba9879215
# proline count 34
# arginine count 14
# lysine count 1
# r/k ratio 14.0
# final aliphatic percent sum 0.3277777777777778
# final acidic percentage sum 0.06944444444444445
# aromaticity 0.1472222222222222
# flexibility sum 345.89441666666664
# flexibility avg 0.9854541785375118
# gravy 0.335555555555555
# PsbA-Anabaena_cylindrica_PCC_7122.fa_2Z87P.faa.final_tree.fa___photo_hmms___9300690c0ffdf81f2a0b39746bd9240521dddb5b6db92fb605c0d157
# proline count 34
# arginine count 13
# lysine count 1
# r/k ratio 13.0
# final aliphatic percent sum 0.33055555555555555
# final acidic percentage sum 0.06666666666666667
# aromaticity 0.1388888888888889
# flexibility sum 345.6707261904764
# flexibility avg 0.9848168837335509
# gravy 0.3522222222222217
# PsbA-Anabaena_cylindrica_PCC_7122.fa_2Z87P.faa.final_tree.fa___photo_hmms___9daaa22dfe5260cc23e6e2c9d748a2d3c6fdfae8d5df6c5bce5bf65f
# proline count 32
# arginine count 12
# lysine count 4
# r/k ratio 3.0
# final aliphatic percent sum 0.3403141361256544
# final acidic percentage sum 0.06544502617801047
# aromaticity 0.12827225130890052
# flexibility sum 367.44642857142844
# flexibility avg 0.9851110685561084
# gravy 0.33376963350785277
# PsbA-Anabaena_cylindrica_PCC_7122.fa_2Z87P.faa.final_tree.fa___photo_hmms___edbc8a4c14a7a9e085bbfcc7d99659c741dd68abf0307ff5a6f1a04d
# proline count 34
# arginine count 13
# lysine count 1
# r/k ratio 13.0
# final aliphatic percent sum 0.3416666666666666
# final acidic percentage sum 0.06944444444444445
# aromaticity 0.1388888888888889
# flexibility sum 345.6984642857144
# flexibility avg 0.98489590964591
# gravy 0.38722222222222213
# PsbA-Anabaena_cylindrica_PCC_7122.fa_2Z87P.faa.final_tree.fa___photo_hmms___3d33f1247cd2ef827e195a54e146220af8b98bbf08be44a4a97e95db
# proline count 35
# arginine count 15
# lysine count 3
# r/k ratio 5.0
# final aliphatic percent sum 0.32478632478632474
# final acidic percentage sum 0.07122507122507123
# aromaticity 0.16524216524216523
# flexibility sum 336.67564285714303
# flexibility avg 0.9844317042606522
# gravy 0.3866096866096875
# PsbA-Anabaena_cylindrica_PCC_7122.fa_2Z87P.faa.final_tree.fa___photo_hmms___5b3919601b1b5e1664dfcace1899ac74a8a0d7850ddd8e18456b68dd
# proline count 35
# arginine count 15
# lysine count 3
# r/k ratio 5.0
# final aliphatic percent sum 0.32478632478632474
# final acidic percentage sum 0.07122507122507123
# aromaticity 0.16524216524216523
# flexibility sum 336.67564285714303
# flexibility avg 0.9844317042606522
# gravy 0.3866096866096875
# PsbA-Anabaena_cylindrica_PCC_7122.fa_2Z87P.faa.final_tree.fa___photo_hmms___74ffec3074a779245b5dde96e13f8ef6b9f182dd260900d888edaa38
# proline count 34
# arginine count 13
# lysine count 1
# r/k ratio 13.0
# final aliphatic percent sum 0.3416666666666666
# final acidic percentage sum 0.07222222222222222
# aromaticity 0.1388888888888889
# flexibility sum 345.7554642857144
# flexibility avg 0.9850583028083032
# gravy 0.38722222222222213
# PsbA-Anabaena_cylindrica_PCC_7122.fa_2Z87P.faa.final_tree.fa___photo_hmms___bdd29a1c41a4401e1adf12ca6a595e041915a9f31956a58d94512223
# proline count 34
# arginine count 13
# lysine count 1
# r/k ratio 13.0
# final aliphatic percent sum 0.33055555555555555
# final acidic percentage sum 0.06666666666666667
# aromaticity 0.1388888888888889
# flexibility sum 345.6707261904764
# flexibility avg 0.9848168837335509
# gravy 0.3522222222222217
# PsbA-Anabaena_sp_4-3.fa_2Z87P.faa.final_tree.fa___photo_hmms___5d367fde6763b2ad6237a35b9e0ff604456b966c2f4d16e2314434f0
# proline count 33
# arginine count 12
# lysine count 1
# r/k ratio 12.0
# final aliphatic percent sum 0.33611111111111114
# final acidic percentage sum 0.06388888888888888
# aromaticity 0.14166666666666666
# flexibility sum 345.7127142857143
# flexibility avg 0.984936507936508
# gravy 0.35999999999999976
# PsbA-Anabaena_sp_4-3.fa_2Z87P.faa.final_tree.fa___photo_hmms___99296f4750a308a6e079ab606b87318df06043bffd11c0acc7f87c6c
# proline count 30
# arginine count 12
# lysine count 2
# r/k ratio 6.0
# final aliphatic percent sum 0.35
# final acidic percentage sum 0.06666666666666667
# aromaticity 0.1361111111111111
# flexibility sum 345.9218214285714
# flexibility avg 0.9855322547822546
# gravy 0.3958333333333337
# PsbA-Anabaena_sp_4-3.fa_2Z87P.faa.final_tree.fa___photo_hmms___3a74defc55063423614e9006d6e43fb4d5edfd384ed91fe62e0d2ded
# proline count 22
# arginine count 11
# lysine count 3
# r/k ratio 3.6666666666666665
# final aliphatic percent sum 0.33198380566801616
# final acidic percentage sum 0.07692307692307693
# aromaticity 0.1700404858299595
# flexibility sum 233.98310714285716
# flexibility avg 0.9831222989195679
# gravy 0.4352226720647768
# PsbA-Anabaena_sp_4-3.fa_2Z87P.faa.final_tree.fa___photo_hmms___003002dd8684dd1c1958daf4e75a53043a819ae6c655d036da1d6af8
# proline count 7
# arginine count 3
# lysine count 0
# final aliphatic percent sum 0.37349397590361444
# final acidic percentage sum 0.07228915662650602
# aromaticity 0.0963855421686747
# flexibility sum 73.23785714285714
# flexibility avg 0.9897007722007721
# gravy 0.2831325301204821
# PsbA-Anabaena_sp_4-3.fa_2Z87P.faa.final_tree.fa___photo_hmms___fe52ada01a80c3ea3185665b2866cfec27410e4357200bfce3092952
# proline count 28
# arginine count 12
# lysine count 1
# r/k ratio 12.0
# final aliphatic percent sum 0.3152866242038217
# final acidic percentage sum 0.06050955414012739
# aromaticity 0.13375796178343952
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [257], in <cell line: 3>()
#      38 aromaticity = x.aromaticity()         # calculating aromaticity
#      39 print("aromaticity", aromaticity)
# ---> 41 flexibility = x.flexibility()         # calculating flexibility
#      42 #print("flexibility", flexibility)
#      43 flexibility_sum = sum(flexibility)
#
# File ~/miniconda3/lib/python3.8/site-packages/Bio/SeqUtils/ProtParam.py:183, in ProteinAnalysis.flexibility(self)
#     181     front = subsequence[j]
#     182     back = subsequence[window_size - j - 1]
# --> 183     score += (flexibilities[front] + flexibilities[back]) * weights[j]
#     185 middle = subsequence[window_size // 2 + 1]
#     186 score += flexibilities[middle]
#
# KeyError: 'X'

# %% [markdown]
# ## Visualizing df

# %%
df = pd.read_csv('PsbA.csv')

print(df.head(10))

# %%
print(df.info())

# %%
df.corr()  # This was for fun bc I'm learning Pandas

# %% [markdown]
# Next would be to plot the data with "import matplotlib.pyplot as plt"
